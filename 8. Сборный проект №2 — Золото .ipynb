# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка данных</a></span><ul class="toc-item"><li><span><a href="#Гистограммы.-Обучабщая-выборка" data-toc-modified-id="Гистограммы.-Обучабщая-выборка-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Гистограммы. Обучабщая выборка</a></span></li><li><span><a href="#Гистограммы.-Тестовая-выборка" data-toc-modified-id="Гистограммы.-Тестовая-выборка-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Гистограммы. Тестовая выборка</a></span></li><li><span><a href="#Гистограммы.-Исходные-данные" data-toc-modified-id="Гистограммы.-Исходные-данные-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Гистограммы. Исходные данные</a></span></li><li><span><a href="#Тепловая-карта" data-toc-modified-id="Тепловая-карта-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Тепловая карта</a></span></li></ul></li><li><span><a href="#Проверка-корректности-расчета-эффективности-обогощения" data-toc-modified-id="Проверка-корректности-расчета-эффективности-обогощения-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверка корректности расчета эффективности обогощения</a></span></li><li><span><a href="#Признаки,-отсутствующие-в-тестовой-выборке" data-toc-modified-id="Признаки,-отсутствующие-в-тестовой-выборке-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Признаки, отсутствующие в тестовой выборке</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Предобработка данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах" data-toc-modified-id="Изменение-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изменение концентрации металлов (Au, Ag, Pb) на различных этапах</a></span></li><li><span><a href="#Распределение-размеров-гранул-исходного-сырья" data-toc-modified-id="Распределение-размеров-гранул-исходного-сырья-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Распределение размеров гранул исходного сырья</a></span></li><li><span><a href="#Суммарная-концентрация-металлов-на-разных-стадиях" data-toc-modified-id="Суммарная-концентрация-металлов-на-разных-стадиях-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Суммарная концентрация металлов на разных стадиях</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Функция-для-вычисления-итоговой-sMAPE" data-toc-modified-id="Функция-для-вычисления-итоговой-sMAPE-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция для вычисления итоговой sMAPE</a></span></li><li><span><a href="#Модели-и-оценкаих-качества-кросс-валидацией" data-toc-modified-id="Модели-и-оценкаих-качества-кросс-валидацией-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Модели и оценкаих качества кросс-валидацией</a></span><ul class="toc-item"><li><span><a href="#Подготовка-датасета" data-toc-modified-id="Подготовка-датасета-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Подготовка датасета</a></span></li></ul></li><li><span><a href="#Модели" data-toc-modified-id="Модели-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Модели</a></span><ul class="toc-item"><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#Решающее-дерево" data-toc-modified-id="Решающее-дерево-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Решающее дерево</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li><li><span><a href="#Лучшая-модель.-Проверка-на-тестовой-выборке" data-toc-modified-id="Лучшая-модель.-Проверка-на-тестовой-выборке-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Лучшая модель. Проверка на тестовой выборке</a></span></li><li><span><a href="#Сравнение-лучшей-модели-с-константной" data-toc-modified-id="Сравнение-лучшей-модели-с-константной-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Сравнение лучшей модели с константной</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# ## Подготовка данных

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pprint import pprint

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, make_scorer
from sklearn.pipeline import Pipeline

from sklearn.dummy import DummyRegressor

from tqdm import tqdm
from datetime import datetime

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# В начале (пункт 1.1.1-1.1.4) много диаграм, скорость загрузки всего блокнота может занять минут 15... ввёл переменную `run_diagram`, если равно **единицы**, то код с диаграммами загружается, если равно **нулю**, то не запускается

# %%
run_diagram = 0

# %%
try:
    data_train = pd.read_csv('/datasets/gold_industry_train.csv')
except:
    data_train = pd.read_csv("https://code.s3.yandex.net/datasets/gold_industry_train.csv")

try:
    data_test = pd.read_csv('/datasets/gold_industry_test.csv')
except:
    data_test = pd.read_csv("https://code.s3.yandex.net/datasets/gold_industry_train.csv")    
    
try:
    data = pd.read_csv('/datasets/gold_industry_full.csv')
except:
    data = pd.read_csv("https://code.s3.yandex.net/datasets/gold_industry_full.csv")

# %%
data_train.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2016-01-15 00:00:00               6.486150               6.100378
# 1  2016-01-15 01:00:00               6.478583               6.161113
# 2  2016-01-15 02:00:00               6.362222               6.116455
# 3  2016-01-15 03:00:00               6.118189               6.043309
# 4  2016-01-15 04:00:00               5.663707               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               2.284912               36.808594               523.546326
# 1               2.266033               35.753385               525.290581
# 2               2.159622               35.971630               530.026610
# 3               2.037807               36.862241               542.590390
# 4               1.786875               34.347666               540.531893
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# ...

# %%
data_test.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2017-12-09 14:59:59               4.365491               6.158718
# 1  2017-12-09 15:59:59               4.362781               6.048130
# 2  2017-12-09 16:59:59               5.081681               6.082745
# 3  2017-12-09 17:59:59               5.145949               6.084374
# 4  2017-12-09 18:59:59               5.735249               6.165220
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               3.875727               39.135119               555.820208
# 1               3.902537               39.713906               544.731687
# 2               4.564078               37.208683               558.155110
# 3               4.768124               36.808874               539.713765
# 4               4.512346               37.810642               558.713584
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# ...

# %%
data.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2016-01-15 00:00:00               6.486150               6.100378
# 1  2016-01-15 01:00:00               6.478583               6.161113
# 2  2016-01-15 02:00:00               6.362222               6.116455
# 3  2016-01-15 03:00:00               6.118189               6.043309
# 4  2016-01-15 04:00:00               5.663707               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               2.284912               36.808594               523.546326
# 1               2.266033               35.753385               525.290581
# 2               2.159622               35.971630               530.026610
# 3               2.037807               36.862241               542.590390
# 4               1.786875               34.347666               540.531893
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# ...

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14579 entries, 0 to 14578
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14579 non-null  object
#  1   rougher.input.feed_au                               14579 non-null  float64
#  2   rougher.input.feed_ag                               14579 non-null  float64
#  3   rougher.input.feed_pb                               14507 non-null  float64
#  4   rougher.input.feed_sol                              14502 non-null  float64
#  5   rougher.input.feed_rate                             14572 non-null  float64
#  6   rougher.input.feed_size                             14478 non-null  float64
#  7   rougher.input.floatbank10_sulfate                   14548 non-null  float64
# ...

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4860 entries, 0 to 4859
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        4860 non-null   object
#  1   rougher.input.feed_au                       4860 non-null   float64
#  2   rougher.input.feed_ag                       4860 non-null   float64
#  3   rougher.input.feed_pb                       4832 non-null   float64
#  4   rougher.input.feed_sol                      4838 non-null   float64
#  5   rougher.input.feed_rate                     4856 non-null   float64
#  6   rougher.input.feed_size                     4816 non-null   float64
#  7   rougher.input.floatbank10_sulfate           4857 non-null   float64
#  8   rougher.input.floatbank10_xanthate          4859 non-null   float64
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   rougher.input.feed_au                               19439 non-null  float64
#  2   rougher.input.feed_ag                               19439 non-null  float64
#  3   rougher.input.feed_pb                               19339 non-null  float64
#  4   rougher.input.feed_sol                              19340 non-null  float64
#  5   rougher.input.feed_rate                             19428 non-null  float64
#  6   rougher.input.feed_size                             19294 non-null  float64
#  7   rougher.input.floatbank10_sulfate                   19405 non-null  float64
# ...

# %%
data_train.describe(include='all').T
# Out:
#                                                       count unique  \
# date                                                  14579  14579
# rougher.input.feed_au                               14579.0    NaN
# rougher.input.feed_ag                               14579.0    NaN
# rougher.input.feed_pb                               14507.0    NaN
# rougher.input.feed_sol                              14502.0    NaN
# rougher.input.feed_rate                             14572.0    NaN
# rougher.input.feed_size                             14478.0    NaN
# rougher.input.floatbank10_sulfate                   14548.0    NaN
# rougher.input.floatbank10_xanthate                  14572.0    NaN
# rougher.state.floatbank10_a_air                     14579.0    NaN
# rougher.state.floatbank10_a_level                   14579.0    NaN
# rougher.state.floatbank10_b_air                     14579.0    NaN
# rougher.state.floatbank10_b_level                   14579.0    NaN
# ...

# %%
data_test.describe(include='all').T
# Out:
#                                              count unique  \
# date                                          4860   4860
# rougher.input.feed_au                       4860.0    NaN
# rougher.input.feed_ag                       4860.0    NaN
# rougher.input.feed_pb                       4832.0    NaN
# rougher.input.feed_sol                      4838.0    NaN
# rougher.input.feed_rate                     4856.0    NaN
# rougher.input.feed_size                     4816.0    NaN
# rougher.input.floatbank10_sulfate           4857.0    NaN
# rougher.input.floatbank10_xanthate          4859.0    NaN
# rougher.state.floatbank10_a_air             4859.0    NaN
# rougher.state.floatbank10_a_level           4859.0    NaN
# rougher.state.floatbank10_b_air             4859.0    NaN
# rougher.state.floatbank10_b_level           4859.0    NaN
# rougher.state.floatbank10_c_air             4859.0    NaN
# rougher.state.floatbank10_c_level           4859.0    NaN
# ...

# %%
data.describe(include='all').T
# Out:
#                                                       count unique  \
# date                                                  19439  19439
# rougher.input.feed_au                               19439.0    NaN
# rougher.input.feed_ag                               19439.0    NaN
# rougher.input.feed_pb                               19339.0    NaN
# rougher.input.feed_sol                              19340.0    NaN
# rougher.input.feed_rate                             19428.0    NaN
# rougher.input.feed_size                             19294.0    NaN
# rougher.input.floatbank10_sulfate                   19405.0    NaN
# rougher.input.floatbank10_xanthate                  19431.0    NaN
# rougher.state.floatbank10_a_air                     19438.0    NaN
# rougher.state.floatbank10_a_level                   19438.0    NaN
# rougher.state.floatbank10_b_air                     19438.0    NaN
# rougher.state.floatbank10_b_level                   19438.0    NaN
# ...

# %%
f"{data_train.duplicated(subset=['date']).sum()}, {data_test.duplicated(subset=['date']).sum()}, {data.duplicated(subset=['date']).sum()}"
# Out:
# '0, 0, 0'

# %%
f"{data_train.duplicated().sum()}, {data_test.duplicated().sum()}, {data.duplicated().sum()}"
# Out:
# '0, 0, 0'

# %% [markdown]
# Дубликатов нет, как полных, так и по дате

# %%
pd.set_option('display.max_rows', 60)
pd.set_option('display.max_columns', 20)

# %% [markdown]
# #### Гистограммы. Обучабщая выборка

# %%
if run_diagram:
    data_train.iloc[:, 0:9].hist(bins=50, figsize=(20,15), edgecolor='black');
#     plt.suptitle('Распределение значений обучающих данных' + "\n", fontsize = 22, color = 'SteelBlue')
#     plt.show()

# %%
if run_diagram:
    start = datetime.now()
    pd.plotting.scatter_matrix(data_train.iloc[:, 0:9], figsize=(20, 20))
    print(datetime.now() - start)

# %%
if run_diagram:
    start = datetime.now()
    data_train.iloc[:, 9:23].hist(bins=50, figsize=(20,20), edgecolor='black');
    print(datetime.now() - start)

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data_train.iloc[:, 9:23], figsize=(20, 20))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
    #     ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data_train.iloc[:, 23:27].hist(bins=50, figsize=(20,10), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data_train.iloc[:, 23:27], figsize=(10, 10))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
        ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data_train.iloc[:, 27:36].hist(bins=50, figsize=(20,15), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data_train.iloc[:, 27:36], figsize=(20, 20))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
    #     ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data_train.iloc[:, 36:40].hist(bins=50, figsize=(20,10), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data_train.iloc[:, 36:40], figsize=(10, 10))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
        ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data_train.iloc[:, 40:48].hist(bins=50, figsize=(20,15), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data_train.iloc[:, 40:48], figsize=(20, 20))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
        ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data_train.iloc[:, 48:56].hist(bins=50, figsize=(20,15), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data_train.iloc[:, 48:56], figsize=(20, 20))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
        ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data_train.iloc[:, 56:73].hist(bins=50, figsize=(20,30), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data_train.iloc[:, 56:73], figsize=(20, 20))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
        ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data_train.iloc[:, 73:78].hist(bins=50, figsize=(20,15), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data_train.iloc[:, 73:78], figsize=(10, 10))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
        ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data_train.iloc[:, 79:].hist(bins=50, figsize=(20,15), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data_train.iloc[:, 79:], figsize=(10, 10))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
        ax.yaxis.label.set_ha('right')

# %% [markdown]
# #### Гистограммы. Тестовая выборка

# %%
if run_diagram:
    data_test.iloc[:, 0:9].hist(bins=50, figsize=(20,15), edgecolor='black');

# %%
if run_diagram:
    pd.plotting.scatter_matrix(data_test.iloc[:, 0:9], figsize=(20, 20));

# %%
if run_diagram:
    data_test.iloc[:, 9:23].hist(bins=50, figsize=(20,20), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data_test.iloc[:, 9:23], figsize=(20, 20))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
    #     ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data_test.iloc[:, 23:27].hist(bins=50, figsize=(20,10), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data_test.iloc[:, 23:27], figsize=(10, 10))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
        ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data_test.iloc[:, 27:35].hist(bins=50, figsize=(20,15), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data_test.iloc[:, 27:35], figsize=(20, 20))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
    #     ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data_test.iloc[:, 35:].hist(bins=50, figsize=(20,10), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data_test.iloc[:, 35:], figsize=(20, 20))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
    #     ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    pd.plotting.scatter_matrix(data_test, figsize=(20, 20));
#     Запускал просто ради интереса, хотелось увидеть всю картинку

# %% [markdown]
# #### Гистограммы. Исходные данные

# %%
if run_diagram:
    data.iloc[:, 0:9].hist(bins=50, figsize=(20,15), edgecolor='black');

# %%
if run_diagram:
    pd.plotting.scatter_matrix(data.iloc[:, 0:9], figsize=(20, 20));

# %%
if run_diagram:
    data.iloc[:, 9:23].hist(bins=50, figsize=(20,20), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data.iloc[:, 9:23], figsize=(20, 20))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
    #     ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data.iloc[:, 23:27].hist(bins=50, figsize=(20,10), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data.iloc[:, 23:27], figsize=(10, 10))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
        ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data.iloc[:, 27:36].hist(bins=50, figsize=(20,15), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data.iloc[:, 27:36], figsize=(20, 20))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
    #     ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data.iloc[:, 36:40].hist(bins=50, figsize=(20,10), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data.iloc[:, 36:40], figsize=(10, 10))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
        ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data.iloc[:, 40:48].hist(bins=50, figsize=(20,15), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data.iloc[:, 40:48], figsize=(20, 20))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
        ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data.iloc[:, 48:56].hist(bins=50, figsize=(20,15), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data.iloc[:, 48:56], figsize=(20, 20))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
        ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data.iloc[:, 56:73].hist(bins=50, figsize=(20,30), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data.iloc[:, 56:73], figsize=(20, 20))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
        ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data.iloc[:, 73:78].hist(bins=50, figsize=(20,15), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data.iloc[:, 73:78], figsize=(10, 10))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
        ax.yaxis.label.set_ha('right')

# %%
if run_diagram:
    data.iloc[:, 79:].hist(bins=50, figsize=(20,15), edgecolor='black');

# %%
if run_diagram:
    axes = pd.plotting.scatter_matrix(data.iloc[:, 79:], figsize=(10, 10))
    for ax in axes.flatten():
        ax.xaxis.label.set_rotation(90)
        ax.yaxis.label.set_rotation(0)
        ax.yaxis.label.set_ha('right')

# %% [markdown]
# #### Тепловая карта

# %%
fig, ax = plt.subplots(figsize=(20,20)) 
sns.heatmap(data_train.corr(), cmap='RdBu_r', vmin=-1, vmax=1, ax=ax);

# %%
fig, ax = plt.subplots(figsize=(20,20)) 
sns.heatmap(data_test.corr(), cmap='RdBu_r', vmin=-1, vmax=1, ax=ax);

# %%
fig, ax = plt.subplots(figsize=(20,20)) 
sns.heatmap(data.corr(), cmap='RdBu_r', vmin=-1, vmax=1, ax=ax);

# %% [markdown]
# На тепловых картах отчётливо видны тёплые пятна и холодные.
# Две большие группы высокой корреляции:
# 1. rougher.state.
#  - floatbank10_b_air
#  - floatbank10_b_level
#  - floatbank10_c_air
#  - floatbank10_c_level
#  - floatbank10_d_air
#  - floatbank10_d_level
#  - floatbank10_e_air
#  - floatbank10_e_level
#  - floatbank10_f_air
#  - floatbank10_f_level
#
#
# 2. secondary_cleaner.state.
#  - floatbank3_a_air
#  - floatbank3_a_level
#  - floatbank3_b_air
#  - floatbank3_b_level
#  - floatbank4_a_air
#  - floatbank4_a_level
#  - floatbank4_b_air
#  - floatbank4_b_level
#  - floatbank5_a_air
#  - floatbank5_a_level
#  - floatbank5_b_air
#  - floatbank5_b_level
#  - floatbank6_a_air
#  - floatbank6_a_level

# %% [markdown]
# **ВЫВОД:**
# Данные представлены в хронологическом порядке, разница между дынными 1 час.
#
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
# В тестовой выборке отсутствую целевые признаки `rougher.output.recovery` (*эффективность обогащения чернового концентрата*) и `final.output.recovery` (*эффективность обогащения чернового концентрата*)
#
#
# Какие-то параметры имею высокую корреляцию, например `primary_cleaner.output.concentrate_pb` и `primary_cleaner.output.concentrate_ag`
# Расчетные параметры `rougher.calculation.*` имеют очень странную картину распределения

# %% [markdown]
# ### Проверка корректности расчета эффективности обогощения

# %% [markdown]
# Эффективность обогащения рассчитывается по формуле

# %% [markdown]
# ![Recovery](https://pictures.s3.yandex.net/resources/Recovery_1576238822.jpg)

# %% [markdown]
#  - **C** — доля золота в концентрате после флотации/очистки (`rougher.output.concentrate_au`);
#  - **F** — доля золота в сырье/концентрате до флотации/очистки (`rougher.input.feed_au`);
#  - **T** — доля золота в отвальных хвостах после флотации/очистки (`rougher.output.tail_au`).

# %%
C = data_train["rougher.output.concentrate_au"]
F = data_train["rougher.input.feed_au"]
T = data_train["rougher.output.tail_au"]

# %%
# Добавляем признак в тестовую выборку
data_train['recovery_check'] = (C * (F - T)) / (F * (C - T)) * 100
# Узнаем средне значение
data_train['recovery_check'].mean()
# Out:
# 82.52119968211336

# %%
# Среднее значение rougher.output.recovery
data_train['rougher.output.recovery'].mean()
# Out:
# 82.52119968211336

# %%
mean_absolute_error(data_train['recovery_check'], data_train['rougher.output.recovery'])
# Out:
# 9.83758577644259e-15

# %% [markdown]
# Получили значение MAE почти равное нулю, а средние значения вообще одинаковые.
# Признак `rougher.output.recovery` расчитан верно. Удалим из тестовой выборки `recovery_check`

# %%
data_train.drop('recovery_check', axis=1, inplace=True)

# %% [markdown]
# ### Признаки, отсутствующие в тестовой выборке

# %%
diff = data.columns.difference(data_test.columns)
for d in diff:
    print(d)
    
print(f"\nОбщее количество недостающих признаков: {len(diff)}")
# Out:
# final.output.concentrate_ag
# final.output.concentrate_au
# final.output.concentrate_pb
# final.output.concentrate_sol
# final.output.recovery
# final.output.tail_ag
# final.output.tail_au
# final.output.tail_pb
# final.output.tail_sol
# primary_cleaner.output.concentrate_ag
# primary_cleaner.output.concentrate_au
# primary_cleaner.output.concentrate_pb
# primary_cleaner.output.concentrate_sol
# primary_cleaner.output.tail_ag
# primary_cleaner.output.tail_au
# primary_cleaner.output.tail_pb
# primary_cleaner.output.tail_sol
# rougher.calculation.au_pb_ratio
# rougher.calculation.floatbank10_sulfate_to_au_feed
# rougher.calculation.floatbank11_sulfate_to_au_feed
# rougher.calculation.sulfate_to_au_concentrate
# rougher.output.concentrate_ag
# rougher.output.concentrate_au
# rougher.output.concentrate_pb
# rougher.output.concentrate_sol
# rougher.output.recovery
# rougher.output.tail_ag
# rougher.output.tail_au
# rougher.output.tail_pb
# rougher.output.tail_sol
# ...

# %% [markdown]
# В списке отсутствующих признаков есть все этапы, большенство из них это концентрат и отвальные хвосты серебра, золота, свинца и солей.
# Недоступны некоторые расчетные (calculation) и выходные (output) характеристики процесса, ведь их невозможно получить либо замерить во время выполнения технологического процесса

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Т.к. данные в выборках отсортированы в хронолочическом порядке, а в будущее "заглядывать" плохо заменим пропуски на последнее (предыдущее) значение - методом `fillna(method='ffill')`
# Вначале посмотрим на пропуски тестовой выборки, следом получим сумму пропусков в обучающей и тестовой выборке. Потом обработаем пропуски

# %%
data_test.isnull().sum()
# Out:
# date                                            0
# rougher.input.feed_au                           0
# rougher.input.feed_ag                           0
# rougher.input.feed_pb                          28
# rougher.input.feed_sol                         22
# rougher.input.feed_rate                         4
# rougher.input.feed_size                        44
# rougher.input.floatbank10_sulfate               3
# rougher.input.floatbank10_xanthate              1
# rougher.state.floatbank10_a_air                 1
# rougher.state.floatbank10_a_level               1
# rougher.state.floatbank10_b_air                 1
# rougher.state.floatbank10_b_level               1
# rougher.state.floatbank10_c_air                 1
# rougher.state.floatbank10_c_level               1
# rougher.state.floatbank10_d_air                 0
# rougher.state.floatbank10_d_level               0
# rougher.state.floatbank10_e_air                 7
# rougher.state.floatbank10_e_level               0
# ...

# %%
print(f"Всего пропусков в исходных данных: {data.isnull().sum().sum()}\n\
Всего пропусков в обучающей выборке: {data_train.isnull().sum().sum()}\n\
Всего пропусков в тестовой выборке: {data_test.isnull().sum().sum()}")
# Out:
# Всего пропусков в исходных данных: 4481
# Всего пропусков в обучающей выборке: 3050
# Всего пропусков в тестовой выборке: 375

# %%
data_train = data_train.fillna(method='ffill')

# %%
data_test = data_test.fillna(method='ffill')

# %%
col_lst = ['rougher.input.feed_au', 'rougher.input.feed_ag', 'rougher.input.feed_pb', 
           'rougher.output.concentrate_au', 'rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 
           'primary_cleaner.output.concentrate_au', 'primary_cleaner.output.concentrate_ag', 'primary_cleaner.output.concentrate_pb', 
           'final.output.concentrate_au', 'final.output.concentrate_ag', 'final.output.concentrate_pb']
data2 = data[col_lst].fillna(method='ffill')

# %% [markdown]
# Т.к. в Пачке сказали не менять исходные данные, но для пункта 2.1 решил всё же убрать пропуски и посмотреть диманику на данных без пропусков

# %% [markdown]
# Так же нам нужно добавить целевый признаки в тестовый датасет. я видимо что-то неправильно понял про исходный датасат... создаем ещё один датасет с целевыми признаками, и заполняем пустоты

# %%
data_to_model = data[['date', 'rougher.output.recovery', 'final.output.recovery']].fillna(method='ffill')
data_to_model.head()
# Out:
#                   date  rougher.output.recovery  final.output.recovery
# 0  2016-01-15 00:00:00                87.107763              70.541216
# 1  2016-01-15 01:00:00                86.843261              69.266198
# 2  2016-01-15 02:00:00                86.842308              68.116445
# 3  2016-01-15 03:00:00                87.226430              68.347543
# 4  2016-01-15 04:00:00                86.688794              66.927016

# %%
print(f"Всего пропусков в обучающей выборке: {data_train.isnull().sum().sum()}\n\
Всего пропусков в тестовой выборке: {data_test.isnull().sum().sum()}")
# Out:
# Всего пропусков в обучающей выборке: 0
# Всего пропусков в тестовой выборке: 0

# %% [markdown]
# Всё Ok! Пропуски устранили

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Изменение концентрации металлов (Au, Ag, Pb) на различных этапах

# %% [markdown]
# Будем изучать признаки:
# - сырьё:
#  - `rougher.input.feed_au`
#  - `rougher.input.feed_ag`
#  - `rougher.input.feed_pb`
#
# - черновой концентрат:
#  - `rougher.output.feed_au`
#  - `rougher.output.feed_ag`
#  - `rougher.output.feed_pb`
#
# - первая очистка:
#  - `primary_cleaner.output.feed_au`
#  - `primary_cleaner.output.feed_ag`
#  - `primary_cleaner.output.feed_pb`
#
# - финальный концентрат:
#  - `final.output.feed_au`
#  - `final.output.feed_ag`
#  - `final.output.feed_pb`

# %% [markdown]
# Посмотрим на распределение данных

# %%
data2.hist(bins=50, figsize=(20,10), edgecolor='black');

# %% [markdown]
# Создадим датиасет из медианных значений, по этим значениям построим график, посмотрим на динамику изменения концентрации металлов

# %%
concentrate_lst = [
    'rougher.input.feed_au', 'rougher.output.concentrate_au', 
    'primary_cleaner.output.concentrate_au', 'final.output.concentrate_au',
    
    'rougher.input.feed_ag', 'rougher.output.concentrate_ag', 
    'primary_cleaner.output.concentrate_ag', 'final.output.concentrate_ag',
    
    'rougher.input.feed_pb', 'rougher.output.concentrate_pb', 
    'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb']

# %%
concentrate_metal_df = pd.DataFrame({
                                    'mean_val': data2.mean()},
                                    index= concentrate_lst)
concentrate_metal_df
# Out:
#                                         mean_val
# rougher.input.feed_au                   8.266097
# rougher.output.concentrate_au          19.772000
# primary_cleaner.output.concentrate_au  32.119400
# final.output.concentrate_au            44.076513
# rougher.input.feed_ag                   8.794927
# rougher.output.concentrate_ag          11.994759
# primary_cleaner.output.concentrate_ag   8.442408
# final.output.concentrate_ag             5.168387
# rougher.input.feed_pb                   3.584516
# rougher.output.concentrate_pb           7.606272
# primary_cleaner.output.concentrate_pb   9.809276
# final.output.concentrate_pb             9.978821

# %%
concentrate_lst2 = [
    'rougher.input.feed', 'rougher.output.concentrate', 
    'primary_cleaner.output.concentrate', 'final.output.concentrate']

# %%
conc_met_df = pd.DataFrame({'au': concentrate_metal_df.iloc[ :4,0].values.tolist(),
                  'ag': concentrate_metal_df.iloc[4:8,0].values.tolist(),
                  'pb': concentrate_metal_df.iloc[8: ,0].values.tolist()},
                 index = ['Сырье', 'Черновой', 'Первая', 'Финал'])
conc_met_df
# Out:
#                  au         ag        pb
# Сырье      8.266097   8.794927  3.584516
# Черновой  19.772000  11.994759  7.606272
# Первая    32.119400   8.442408  9.809276
# Финал     44.076513   5.168387  9.978821

# %%
plt.figure(figsize=(15, 8))
ax = sns.lineplot(data=conc_met_df)
ax.set(xlabel='Этапы и металлы', ylabel='Концентрация')
plt.title('Изменение концентрации металлов (Au, Ag, Pb) на различных этапах' + "\n", loc="left",
          fontsize = 22, color = 'SteelBlue');

# %%
print(f"В концентрации золота нет ничего удивительно, с каждым этапом очистки его концентрация увеличивается, \
данные ведь с \nзолотободывающего рудника. Причём Концентрация увеличивается плавно, равномерно\n\
Концентрация серебра имеет максимально значение на этапе чернового концетрата, далее его концентрация уменьшается\n\
Концентрация свинца на возрастает до до этапа первой очистки, далее держится на одном уровне\n\n\
Медианная финальная концентрация золота равна ~ {round(concentrate_metal_df.loc['final.output.concentrate_au','mean_val'],2)}\n\
Концентрация золота в финальном концентрате по сравнению с сырьем выросла в \
{round(concentrate_metal_df.loc['final.output.concentrate_au','mean_val'] / concentrate_metal_df.loc['rougher.input.feed_au','mean_val'],2)}")
# Out:
# В концентрации золота нет ничего удивительно, с каждым этапом очистки его концентрация увеличивается, данные ведь с
# золотободывающего рудника. Причём Концентрация увеличивается плавно, равномерно
# Концентрация серебра имеет максимально значение на этапе чернового концетрата, далее его концентрация уменьшается
# Концентрация свинца на возрастает до до этапа первой очистки, далее держится на одном уровне
#
# Медианная финальная концентрация золота равна ~ 44.08
# Концентрация золота в финальном концентрате по сравнению с сырьем выросла в 5.33

# %% [markdown]
# ### Распределение размеров гранул исходного сырья

# %% [markdown]
# Оценим призна `rougher.input.feed_size` обучающей и тестовой выборки
# Если распределения сильно отличаются друг от друга, оценка модели будет неправильной

# %%
fig, axes = plt.subplots(figsize=(17, 10))

fig.suptitle('Распределение размеров гранул исходного сырья', fontsize = 22, color = 'SteelBlue');

data_train['rougher.input.feed_size'].hist(bins=150, edgecolor='black', range=[0, 500], alpha = 0.4, label='train', 
                                           weights=np.ones_like (data_train['rougher.input.feed_size'])
                                           / len (data_train['rougher.input.feed_size']));
data_test['rougher.input.feed_size'].hist(bins=150, edgecolor='black', range=[0, 500], alpha = 0.4, label='test',
                                          weights=np.ones_like (data_test['rougher.input.feed_size'])
                                          / len (data_test['rougher.input.feed_size']))
plt.legend()
plt.show()

# %% [markdown]
# График помог убедиться, что тут с данными всё ОК

# %% [markdown]
# ### Суммарная концентрация металлов на разных стадиях

# %% [markdown]
# Посмотрим на суммарную концентрацию металлов на стадиях:
# - Сырье
# - Черновой концентрат
# - Концентрат после первой очистки
# - Финальный концентрат
# ПОстроим графики:

# %%
sum_concentrate_metal_df = pd.DataFrame({
                                    'sum_val_feed': data2[['rougher.input.feed_au', 
                                                           'rougher.input.feed_ag', 
                                                           'rougher.input.feed_pb']].sum(axis=1),
                                    'sum_val_rougher_conc': data2[['rougher.output.concentrate_au', 
                                                                   'rougher.output.concentrate_ag', 
                                                                   'rougher.output.concentrate_pb']].sum(axis=1),
                                    'sum_val_primary': data2[['primary_cleaner.output.concentrate_au', 
                                                              'primary_cleaner.output.concentrate_ag',
                                                              'primary_cleaner.output.concentrate_pb']].sum(axis=1),
                                    'sum_val_final': data2[['final.output.concentrate_au',
                                                            'final.output.concentrate_ag',
                                                            'final.output.concentrate_pb']].sum(axis=1)},
#                                     index= concentrate_lst
)
sum_concentrate_metal_df.head()
# Out:
#    sum_val_feed  sum_val_rougher_conc  sum_val_primary  sum_val_final
# 0     14.871440             38.395653        53.111627      58.137072
# 1     14.905729             38.945647        53.174338      58.699942
# 2     14.638299             38.649756        52.927464      58.927421
# 3     14.199305             38.411473        43.979185      58.714815
# 4     13.511497             38.867359        52.121146      59.065251

# %%
fig, axes = plt.subplots(figsize=(17, 10))

fig.suptitle('Суммарная концентрация металлов на разных стадиях', fontsize = 22, color = 'SteelBlue');

sum_concentrate_metal_df['sum_val_feed'].hist(bins=150, edgecolor='black', alpha = 0.4, label='Сырье');
sum_concentrate_metal_df['sum_val_rougher_conc'].hist(bins=150, edgecolor='black', alpha = 0.4, label='Черновой концентрат');
sum_concentrate_metal_df['sum_val_primary'].hist(bins=150, edgecolor='black', alpha = 0.4, label='Концентрат после первой очистки');
sum_concentrate_metal_df['sum_val_final'].hist(bins=150, edgecolor='black', alpha = 0.4, label='Финальный концентрат');
plt.legend()
plt.show()

# %%
sum_concentrate_metal_df.max()
# Out:
# sum_val_feed            33.498784
# sum_val_rougher_conc    55.568687
# sum_val_primary         60.269003
# sum_val_final           64.968881
# dtype: float64

# %%
print(f"После каждой стадии обработки суммарная концентрация металлов увеличиваестя.\n\
На каждом этапе очистки концентрация металлов увеличивается. Также видны нули\n\
Максимальная концентрация металлов на разных стадиях:\n\
- Сырье: {round(sum_concentrate_metal_df['sum_val_feed'].max(),1)}\n\
- Черновой концентрат: {round(sum_concentrate_metal_df['sum_val_rougher_conc'].max(),1)}\n\
- Концентрат после первой очистки: {round(sum_concentrate_metal_df['sum_val_primary'].max(),1)}\n\
- Финальный концентрат: {round(sum_concentrate_metal_df['sum_val_final'].max(),1)}\n\
Из графика видно, что после черновой обработки данные имеют нормальное распределение")
# Out:
# После каждой стадии обработки суммарная концентрация металлов увеличиваестя.
# На каждом этапе очистки концентрация металлов увеличивается. Также видны нули
# Максимальная концентрация металлов на разных стадиях:
# - Сырье: 33.5
# - Черновой концентрат: 55.6
# - Концентрат после первой очистки: 60.3
# - Финальный концентрат: 65.0
# Из графика видно, что после черновой обработки данные имеют нормальное распределение

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Функция для вычисления итоговой sMAPE

# %% [markdown]
# **sMAPE** (англ. *Symmetric Mean Absolute Percentage Error*, «симметричное среднее абсолютное процентное отклонение»).
# Она похожа на MAE, но выражается не в абсолютных величинах, а в относительных. Она одинаково учитывает масштаб и целевого признака, и предсказания.

# %% [markdown]
# Формула sMAPE

# %% [markdown]
# ![sMAPE](https://pictures.s3.yandex.net/resources/smape_1576239058.jpg)

# %%
def smape(y, pred):
    smape = 1/len(y) * np.sum(2 * np.abs(y - pred) / (np.abs(y) + np.abs(pred))*100)
    return smape

# %% [markdown]
# Формула итогово sMAPE

# %% [markdown]
# ![Итоговое sMAPE](https://pictures.s3.yandex.net/resources/_smape_1576239054.jpg)

# %%
def smape_final(r, f):
    return 0.25 * r + 0.75 * f

# %% [markdown]
# ### Модели и оценкаих качества кросс-валидацией

# %% [markdown]
# #### Подготовка датасета

# %% [markdown]
# Уберем из обучающего и тестового датасета объекты с нулевой суммарной концентрацией металлов на разных этапах очистки

# %%
index_to_drop = set(sum_concentrate_metal_df[sum_concentrate_metal_df['sum_val_rougher_conc'] == 0].index)
index_to_drop.update(
    set(sum_concentrate_metal_df[sum_concentrate_metal_df['sum_val_primary'] == 0].index),
    set(sum_concentrate_metal_df[sum_concentrate_metal_df['sum_val_final'] == 0].index))

# %%
print(f"Длина массива до обработки:\nОбучающий дс: {len(data_train)}\nТестовый дс: {len(data_test)}")
# Out:
# Длина массива до обработки:
# Обучающий дс: 14579
# Тестовый дс: 4860

# %%
data_train.drop(index_to_drop, inplace=True, errors='ignore')

# %%
data_test.drop(index_to_drop, inplace=True, errors='ignore')

# %%
print(f"Длина массива ПОСЛЕ обработки:\nОбучающий дс: {len(data_train)}\nТестовый дс: {len(data_test)}")
# Out:
# Длина массива ПОСЛЕ обработки:
# Обучающий дс: 13988
# Тестовый дс: 4726

# %% [markdown]
# Добавим в тестовую выборку целевые признаки. Возьмем их из исходных данных

# %%
data_test = data_test.merge(data_to_model, how='left', on='date')

# %% [markdown]
# Создадим список признаков, отсутствующих в тестовой выборке. Уберем этот список признаков из обучающей выборке

# %%
diff2 = list(set(diff) - set(data_test.columns))

# %%
data_train.drop(diff2, inplace=True, errors='ignore', axis=1)

# %% [markdown]
# Удалим признак 'date'

# %%
data_test.drop(['date'], axis=1, inplace=True)
data_train.drop(['date'], axis=1, inplace=True)

# %% [markdown]
# Создадим выборки feature и target на этапе чернового и финального концетрата для тестовой и обучающей выборки

# %%
X_train_r = X_train_f = data_train.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
y_train_r = data_train['rougher.output.recovery']
y_train_f = data_train['final.output.recovery']

X_test_r = X_test_f = data_test.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
y_test_r = data_test['rougher.output.recovery']
y_test_f = data_test['final.output.recovery']

# %%
print(f"Посмотрим на размеры полученных выборок:\n\
{X_train_r.shape}/{X_train_f.shape}\n{y_train_r.shape}/{y_train_f.shape}\n\n\
{X_test_r.shape}/{X_test_f.shape}\n{y_test_r.shape}/{y_test_f.shape}")
# Out:
# (13988, 52)/(13988, 52)
# (13988,)/(13988,)
#
# (4726, 52)/(4726, 52)
# (4726,)/(4726,)

# %% [markdown]
# ### Модели

# %%
model1 = LinearRegression()
model2 = DecisionTreeRegressor(random_state=12345)
model3 = RandomForestRegressor(random_state=12345)

# %%
smape_make_scorer = make_scorer(smape, greater_is_better=False)

# %% [markdown]
# #### Линейная регрессия

# %% [markdown]
# Создадим модель линейной регресси, подберем параметры, найдём sMAPE

# %%
start = datetime.now()

params1 = {
           'fit_intercept': [True,False],
           'normalize': [True,False],
           'copy_X': [True, False],
          }
model1_grid = GridSearchCV(model1, params1, cv=5, scoring=smape_make_scorer)
model1_grid.fit(X_train_r, y_train_r)

print('Подобранные гиперпараметры:', model1_grid.best_params_)
print('sMAPE:', -model1_grid.best_score_)
print(datetime.now() - start)
# Out:
# Подобранные гиперпараметры: {'copy_X': True, 'fit_intercept': True, 'normalize': True}
# sMAPE: 7.039186251866033
# 0:00:29.435376

# %%
start = datetime.now()

lr_r = cross_val_score(model1_grid, X_train_r, y_train_r, scoring=smape_make_scorer, cv=5, n_jobs=-1)
lr_f =  cross_val_score(model1_grid, X_train_f, y_train_f, scoring=smape_make_scorer, cv=5, n_jobs=-1)

print('Итоговое sMAPE для линейной регрессии:', -smape_final(lr_r, lr_f).mean())
print(datetime.now() - start)
# Out:
# Итоговое sMAPE для линейной регрессии: 8.931572253995688
# 0:04:22.705998

# %% [markdown]
# #### Решающее дерево

# %% [markdown]
# Создаём модели отдельно для этапа чернового концетрата и финального концетрата, подбираем параметры и оцениваем качество модели кросс-валидацией, посмотрим на итоговое sMAPE

# %%
start = datetime.now()

params2 = {
           'max_depth': [10, 20, 30, 40, None],
           'max_features': ['auto', 'sqrt'],
           'min_samples_leaf': [1, 2, 4],
           'min_samples_split': [2, 5, 10],
          }

model2_grid_r = GridSearchCV(model2, params2, cv=3, scoring=smape_make_scorer)
model2_grid_r.fit(X_train_r, y_train_r)

print('Подобранные гиперпараметры:', model2_grid_r.best_params_)
print('sMAPE:', -model2_grid_r.best_score_)
print(datetime.now() - start)
# Out:
# Подобранные гиперпараметры: {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# sMAPE: 7.620851522058417
# 0:01:36.977919

# %%
start = datetime.now()

params2 = {
           'max_depth': [10, 20, 30, 40, None],
           'max_features': ['auto', 'sqrt'],
           'min_samples_leaf': [1, 2, 4],
           'min_samples_split': [2, 5, 10],
          }

model2_grid_f = GridSearchCV(model2, params2, cv=3, scoring=smape_make_scorer)
model2_grid_f.fit(X_train_f, y_train_f)

print('Подобранные гиперпараметры:', model2_grid_f.best_params_)
print('sMAPE:', -model2_grid_f.best_score_)
print(datetime.now() - start)
# Out:
# Подобранные гиперпараметры: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# sMAPE: 12.405679401444162
# 0:01:42.060454

# %%
start = datetime.now()

dtr_r = cross_val_score(model2_grid_r, X_train_r, y_train_r, scoring=smape_make_scorer, cv=5, n_jobs=-1)
dtr_f = cross_val_score(model2_grid_f, X_train_f, y_train_f, scoring=smape_make_scorer, cv=5, n_jobs=-1)

print('Итоговое sMAPE для решающего дерева:', -smape_final(dtr_r, dtr_f).mean())
print(datetime.now() - start)
# Out:
# Итоговое sMAPE для решающего дерева: 12.302225493618238
# 0:12:49.354424

# %% [markdown]
# #### Случайный лес

# %% [markdown]
# По аналогии решающим деревом создаём две модели, подбираем параметры, оцениваем кросс-валидацией

# %%
start = datetime.now()

params3 = {
            'max_depth': [10, 14, None],
            'max_features': ['auto', 'sqrt'],
            'min_samples_leaf': [2, 4],
            'min_samples_split': [4, 10],
            'n_estimators': [5],
}

model3_grid_r = GridSearchCV(model3, params3, cv=3, scoring=smape_make_scorer)
model3_grid_r.fit(X_train_r, y_train_r)

print('Подобранные гиперпараметры:', model3_grid_r.best_params_)
print('sMAPE:', -model3_grid_r.best_score_)
print(datetime.now() - start)
# Out:
# Подобранные гиперпараметры: {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 5}
# sMAPE: 6.886655431857986
# 0:01:07.659093

# %%
start = datetime.now()

params3 = {
            'max_depth': [10, 14, None],
            'max_features': ['auto', 'sqrt'],
            'min_samples_leaf': [2, 4],
            'min_samples_split': [4, 10],
            'n_estimators': [5],
}

model3_grid_f = GridSearchCV(model3, params3, cv=3, scoring=smape_make_scorer)
model3_grid_f.fit(X_train_f, y_train_f)

print('Подобранные гиперпараметры:', model3_grid_f.best_params_)
print('sMAPE:', -model3_grid_f.best_score_)
print(datetime.now() - start)
# Out:
# Подобранные гиперпараметры: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 5}
# sMAPE: 10.252428354984895
# 0:01:10.850034

# %%
start = datetime.now()

rfr_r = cross_val_score(model3_grid_r, X_train_r, y_train_r, scoring=smape_make_scorer, cv=5, n_jobs=-1)
rfr_f = cross_val_score(model3_grid_f, X_train_f, y_train_f, scoring=smape_make_scorer, cv=5, n_jobs=-1)
print('Итоговое sMAPE для решающего дерева:', -smape_final(rfr_r, rfr_f).mean())
print(datetime.now() - start)
# Out:
# Итоговое sMAPE для решающего дерева: 9.103978448175672
# 0:09:09.393652

# %% [markdown]
# ### Лучшая модель. Проверка на тестовой выборке

# %% [markdown]
# Ещё раз посомтрим на итоговое sMAPE всех обученных моделей, найдём лучшую пару, проверим их на тестовой выборке

# %%
print(f"Линейная регрессия:\n{-model1_grid.best_score_}\n\n\
Решающее дерево:\n{-model2_grid_r.best_score_} - Черновой концентрат\n\
{-model2_grid_f.best_score_} - Финальный концентрат\n\n\
Случайный лес:\n{-model3_grid_r.best_score_} - Черновой концентрат\n\
{-model3_grid_f.best_score_} - Финальный концентрат")
# Out:
# Линейная регрессия:
# 7.039186251866033
#
# Решающее дерево:
# 7.620851522058417 - Черновой концентрат
# 12.405679401444162 - Финальный концентрат
#
# Случайный лес:
# 6.886655431857986 - Черновой концентрат
# 10.252428354984895 - Финальный концентрат

# %% [markdown]
# Очевидно, что из-за плохих вариантов параметров для подборо случайный лес не получил самую лучшую оценку

# %%
print(f"Лучшие оценки у Решающего дерева: Создадим модели с подобранными параметрами для двух этапов очистки:\n\
Черновой концентрат:\n{model2_grid_r.best_params_}\n\n\
Финальный концентрат:\n{model2_grid_f.best_params_}")
# Out:
# Лучшие оценки у Решающего дерева: Создадим модели с подобранными параметрами для двух этапов очистки:
# Черновой концентрат:
# {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Финальный концентрат:
# {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}

# %%
model2_grid_r.best_params_['max_depth']
# Out:
# 20

# %%
best_model_r = DecisionTreeRegressor(random_state=12345,
                                     max_depth = model2_grid_r.best_params_['max_depth'],
                                     max_features = model2_grid_r.best_params_['max_features'],
                                     min_samples_leaf = model2_grid_r.best_params_['min_samples_leaf'],
                                     min_samples_split = model2_grid_r.best_params_['min_samples_split']
    )
best_model_r.fit(X_train_r, y_train_r)
pred_r = best_model_r.predict(X_test_r)
smape_r = smape(y_test_r, pred_r)
print(smape_r)
# Out:
# 3.862988150048137

# %%
best_model_f = DecisionTreeRegressor(random_state=12345,
                                     max_depth = model2_grid_f.best_params_['max_depth'],
                                     max_features = model2_grid_f.best_params_['max_features'],
                                     min_samples_leaf = model2_grid_f.best_params_['min_samples_leaf'],
                                     min_samples_split = model2_grid_f.best_params_['min_samples_split']
    )
best_model_f.fit(X_train_f, y_train_f)
pred_f = best_model_f.predict(X_test_f)
smape_f = smape(y_test_f, pred_f)
print(smape_f)
# Out:
# 8.272511011352341

# %%
print(f"Итоговое sMAPE на тестовой выборке {round(smape_final(smape_r, smape_f), 2)}, \
это меньше, чем при подборе модели {round(-smape_final(rfr_r, rfr_f).mean(), 2)} - значит модель подобрана плохо")
# Out:
# Итоговое sMAPE на тестовой выборке 7.17, это меньше, чем при подборе модели 9.1 - значит модель подобрана плохо

# %% [markdown]
# ### Сравнение лучшей модели с константной

# %% [markdown]
# Создадим константную модель используя алгоритм DummyRegressor из пакета sklearn

# %%
dr_model_r = DummyRegressor(strategy="median")
dr_model_r.fit(X_train_r, y_train_r)
pred_dr_r = dr_model_r.predict(X_test_r)
smape_dr_r = smape(y_test_r, pred_dr_r)

# %%
dr_model_f = DummyRegressor(strategy="median")
dr_model_f.fit(X_train_f, y_train_f)
pred_dr_f = dr_model_f.predict(X_test_f)
smape_dr_f = smape(y_test_f, pred_dr_f)

# %%
dr_smape = round(smape_final(smape_dr_r, smape_dr_f), 2)
print(f"Итоговое sMAPE на тестовой выборке {dr_smape}")
# Out:
# Итоговое sMAPE на тестовой выборке 8.35

# %%
print(f"Итоговое sMAPE лучшей модели на тестовой выборке: {round(smape_final(smape_r, smape_f), 2)}\n\
Итоговое sMAPE константной модели на тестовой выборке: {dr_smape}")
# Out:
# Итоговое sMAPE лучшей модели на тестовой выборке: 7.17
# Итоговое sMAPE константной модели на тестовой выборке: 8.35

# %% [markdown]
# Константная модель сработала лучше - это следствие плохо подобранных значений гиперпараметров нашей модели

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **Входные данные**
# Были предоставлены обучающие, тестовые и исходные данные.
# В тестовой выборке часть признаков отсутствовала, по этому и из обучающей выборке они были убраны
# В данных присутствовали небольшие пропуски и аномалии, одни заполнили следующими по списку значениями, других удалили
#
# **Анализ данных**
# Посмотрели на концентрации разных металлов, всё выглядит нормально.
# Посмотрели на размеры гранул исходного сырья в обучающей и тестовых выборках - тоже всё хорошо
# Убедились, что после каждой стадии очистки суммарное количество металла возрастает, концентрация золота имеет почти линейное увеличение концентрации
#
# **Модель и результаты**
# Начали подбор моделей на обучающих данных. Отдельно создали модели для чернового концентрата и для финального концентрата.
# По результатам подбора модели выбрали решающее дерево.
# При проверки модели увидели, что модель была плохо обучена - это следствие урезанных вариантов значений гиперпараметров, т.к. модель очень долго подбирает параметры, а время кросс-валидационнионной оценки возрастает в разы
